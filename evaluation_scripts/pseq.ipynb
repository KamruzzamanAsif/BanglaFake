# %%
# real = "/content/drive/MyDrive/ML-Project_Team_minions/Survey Audio/real_04.wav"
# fake = "/content/drive/MyDrive/ML-Project_Team_minions/Survey Audio/fake_04.wav"

# vits2
real = "/content/drive/MyDrive/ML-Project_Team_minions/Survey Audio/Test/ground_vits.wav"
fake = "/content/drive/MyDrive/ML-Project_Team_minions/Survey Audio/Test/fake_vits.wav"

# %% [markdown]
# ## Current and Final PESQ calculation

# %%
# %%capture
# !pip install pesq

# %%
# %%capture
# !pip install librosa

# %% [markdown]
# ## PESQ

# %%
from pesq import pesq
from scipy.io import wavfile
import librosa
import os
import numpy as np

def calculate_pesq_for_batch(real_audio_dir, fake_audio_dir):
    """
    Calculate PESQ score for a batch of real and fake audio files.

    Args:
        real_audio_dir (str): Directory containing real audio files.
        fake_audio_dir (str): Directory containing fake audio files.

    Returns:
        float: Average PESQ score for the batch.
    """
    pesq_scores = []

    # Ensure the directories contain corresponding audio files
    real_files = sorted([os.path.join(real_audio_dir, f) for f in os.listdir(real_audio_dir) if f.endswith('.wav')])
    fake_files = sorted([os.path.join(fake_audio_dir, f) for f in os.listdir(fake_audio_dir) if f.endswith('.wav')])

    print("REAL FILES: ", real_files)
    print("FAKE FILES: ", fake_files)

    if len(real_files) != len(fake_files):
        raise ValueError("Number of files in real_audio_dir and fake_audio_dir must be the same.")

    for real_path, fake_path in zip(real_files, fake_files):
        # Load audio files
        ref_rate, ref_audio = wavfile.read(real_path)
        deg_rate, deg_audio = wavfile.read(fake_path)

        # Resample to 16000 Hz
        ref_audio_resampled = librosa.resample(ref_audio.astype(float), orig_sr=ref_rate, target_sr=16000)
        deg_audio_resampled = librosa.resample(deg_audio.astype(float), orig_sr=deg_rate, target_sr=16000)

        # Compute PESQ score
        try:
            score = pesq(16000, ref_audio, deg_audio, 'wb')  # 'wb' for wideband
            pesq_scores.append(score)
            print(f"PESQ Score for {os.path.basename(real_path)} and {os.path.basename(fake_path)}: {score}")
        except Exception as e:
            print(f"Error processing {real_path} and {fake_path}: {e}")
            continue

    # Calculate average PESQ score
    average_pesq = np.mean(pesq_scores) if pesq_scores else 0.0
    return average_pesq

# Example
real_audio_dir = "/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100"
# fake_audio_dir = "/content/drive/MyDrive/ML-Project_Team_minions/evaluation/fake_70K"
# fake_audio_dir = "/content/drive/MyDrive/ML-Project_Team_minions/evaluation/fake_130K"
# fake_audio_dir = "/content/drive/MyDrive/ML-Project_Team_minions/evaluation/fake_140K"
# fake_audio_dir = "/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_70K"
fake_audio_dir = "/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K"
# fake_audio_dir = "/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_140K"

average_pesq_score = calculate_pesq_for_batch(real_audio_dir, fake_audio_dir)
print(f"Average PESQ Score for the batch: {average_pesq_score}")
# Out:
# REAL FILES:  ['/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_01083.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_01264.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_01726.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_01800.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_01817.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_02012.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_02277.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_02594.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_03169.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_03196.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_03226.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_03343.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_03572.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_06034.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_06131.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_06256.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_06425.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_06461.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_07047.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_07049.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_07063.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_07096.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_07282.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_07516.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_07795.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_08143.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_08623.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_09110.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_09273.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_09630.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_10014.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_10198.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_10239.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_10474.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_10617.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_10715.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_10765.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_10888.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_11058.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_11225.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_11241.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_11254.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_11261.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_real_100/real_11354.wav', '/content/drive/MyDrive/ML ...
# FAKE FILES:  ['/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_01083.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_01264.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_01726.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_01800.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_01817.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_02012.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_02277.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_02594.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_03169.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_03196.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_03226.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_03343.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_03572.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_06034.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_06131.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_06256.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_06425.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_06461.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_07047.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_07049.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_07063.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_07096.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_07282.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_07516.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_07795.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_08143.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_08623.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_09110.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_09273.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_09630.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_10014.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_10198.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_10239.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_10474.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_10617.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_10715.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_10765.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_10888.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_11058.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_11225.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_11241.wav', '/content/drive/MyDrive/ML-Project_Team_minions/evaluation/eval_fake_100_130K/fake_11254.wa ...
# PESQ Score for real_01083.wav and fake_01083.wav: 1.1277154684066772
# PESQ Score for real_01264.wav and fake_01264.wav: 1.1697748899459839
# PESQ Score for real_01726.wav and fake_01726.wav: 1.1667144298553467
# PESQ Score for real_01800.wav and fake_01800.wav: 1.0957388877868652
# PESQ Score for real_01817.wav and fake_01817.wav: 1.247096061706543
# PESQ Score for real_02012.wav and fake_02012.wav: 1.7696819305419922
# PESQ Score for real_02277.wav and fake_02277.wav: 1.1051995754241943
# PESQ Score for real_02594.wav and fake_02594.wav: 1.21895432472229
# PESQ Score for real_03169.wav and fake_03169.wav: 1.0651499032974243
# PESQ Score for real_03196.wav and fake_03196.wav: 1.5515456199645996
# PESQ Score for real_03226.wav and fake_03226.wav: 1.2229321002960205
# PESQ Score for real_03343.wav and fake_03343.wav: 2.529971122741699
# PESQ Score for real_03572.wav and fake_03572.wav: 2.33735990524292
# PESQ Score for real_06034.wav and fake_06034.wav: 1.4627256393432617
# PESQ Score for real_06131.wav and fake_06131.wav: 3.779691219329834
# PESQ Score for real_06256.wav and fake_06256.wav: 2.072723388671875
# PESQ Score for real_06425.wav and fake_06425.wav: 1.2464524507522583
# PESQ Score for real_06461.wav and fake_06461.wav: 1.1716386079788208
# PESQ Score for real_07047.wav and fake_07047.wav: 1.1316217184066772
# PESQ Score for real_07049.wav and fake_07049.wav: 1.8743584156036377
# PESQ Score for real_07063.wav and fake_07063.wav: 1.5328025817871094
# PESQ Score for real_07096.wav and fake_07096.wav: 1.9421124458312988
# PESQ Score for real_07282.wav and fake_07282.wav: 2.0667033195495605
# PESQ Score for real_07516.wav and fake_07516.wav: 1.0404325723648071
# PESQ Score for real_07795.wav and fake_07795.wav: 1.5743173360824585
# PESQ Score for real_08143.wav and fake_08143.wav: 1.0488497018814087
# PESQ Score for real_08623.wav and fake_08623.wav: 1.3858880996704102
# PESQ Score for real_09110.wav and fake_09110.wav: 1.351071834564209
# PESQ Score for real_09273.wav and fake_09273.wav: 1.4110323190689087
# PESQ Score for real_09630.wav and fake_09630.wav: 1.3774995803833008
# PESQ Score for real_10014.wav and fake_10014.wav: 1.1224501132965088
# PESQ Score for real_10198.wav and fake_10198.wav: 1.266514539718628
# PESQ Score for real_10239.wav and fake_10239.wav: 1.1876519918441772
# PESQ Score for real_10474.wav and fake_10474.wav: 1.6363493204116821
# PESQ Score for real_10617.wav and fake_10617.wav: 1.3818202018737793
# PESQ Score for real_10715.wav and fake_10715.wav: 1.1035858392715454
# PESQ Score for real_10765.wav and fake_10765.wav: 1.1303236484527588
# PESQ Score for real_10888.wav and fake_10888.wav: 1.2974472045898438
# PESQ Score for real_11058.wav and fake_11058.wav: 1.2080904245376587
# PESQ Score for real_11225.wav and fake_11225.wav: 1.3200080394744873
# PESQ Score for real_11241.wav and fake_11241.wav: 1.0870413780212402
# PESQ Score for real_11254.wav and fake_11254.wav: 1.6380913257598877
# PESQ Score for real_11261.wav and fake_11261.wav: 1.200147271156311
# PESQ Score for real_11354.wav and fake_11354.wav: 1.1794277429580688
# PESQ Score for real_11426.wav and fake_11426.wav: 1.0976102352142334
# PESQ Score for real_11481.wav and fake_11481.wav: 1.1939364671707153
# PESQ Score for real_11552.wav and fake_11552.wav: 1.4508247375488281
# PESQ Score for real_11627.wav and fake_11627.wav: 1.160183072090149
# PESQ Score for real_12360.wav and fake_12360.wav: 1.2293713092803955
# PESQ Score for real_12586.wav and fake_12586.wav: 1.1151081323623657
# PESQ Score for real_12865.wav and fake_12865.wav: 1.2526612281799316
# PESQ Score for real_13051.wav and fake_13051.wav: 1.113303303718567
# PESQ Score for real_13068.wav and fake_13068.wav: 1.1157399415969849
# PESQ Score for real_13143.wav and fake_13143.wav: 1.6777265071868896
# PESQ Score for real_13518.wav and fake_13518.wav: 1.1290702819824219
# PESQ Score for real_14150.wav and fake_14150.wav: 1.1091368198394775
# PESQ Score for real_14305.wav and fake_14305.wav: 1.74319326877594
# PESQ Score for real_14547.wav and fake_14547.wav: 1.1860591173171997
# PESQ Score for real_15027.wav and fake_15027.wav: 1.1915175914764404
# PESQ Score for real_15148.wav and fake_15148.wav: 1.4202840328216553
# PESQ Score for real_15191.wav and fake_15191.wav: 1.2831976413726807
# PESQ Score for real_15377.wav and fake_15377.wav: 1.2859034538269043
# PESQ Score for real_15409.wav and fake_15409.wav: 1.0780190229415894
# PESQ Score for real_15414.wav and fake_15414.wav: 1.2464982271194458
# PESQ Score for real_15545.wav and fake_15545.wav: 1.325136423110962
# PESQ Score for real_16178.wav and fake_16178.wav: 1.7917420864105225
# PESQ Score for real_16229.wav and fake_16229.wav: 1.9864320755004883
# PESQ Score for real_16326.wav and fake_16326.wav: 1.0849809646606445
# PESQ Score for real_16735.wav and fake_16735.wav: 1.3878408670425415
# PESQ Score for real_16747.wav and fake_16747.wav: 1.044130563735962
# PESQ Score for real_17104.wav and fake_17104.wav: 1.0328905582427979
# PESQ Score for real_17319.wav and fake_17319.wav: 1.3189243078231812
# PESQ Score for real_17338.wav and fake_17338.wav: 1.1608010530471802
# PESQ Score for real_17401.wav and fake_17401.wav: 1.1872382164001465
# PESQ Score for real_17475.wav and fake_17475.wav: 1.3386884927749634
# PESQ Score for real_17731.wav and fake_17731.wav: 1.8266234397888184
# PESQ Score for real_18195.wav and fake_18195.wav: 1.6043052673339844
# PESQ Score for real_18282.wav and fake_18282.wav: 2.3996548652648926
# PESQ Score for real_18339.wav and fake_18339.wav: 1.261649489402771
# PESQ Score for real_18394.wav and fake_18394.wav: 1.4310283660888672
# PESQ Score for real_18586.wav and fake_18586.wav: 2.378918170928955
# PESQ Score for real_18681.wav and fake_18681.wav: 2.9230120182037354
# PESQ Score for real_18955.wav and fake_18955.wav: 1.4038077592849731
# PESQ Score for real_18963.wav and fake_18963.wav: 1.6144182682037354
# PESQ Score for real_19016.wav and fake_19016.wav: 1.1207599639892578
# PESQ Score for real_19030.wav and fake_19030.wav: 1.3129538297653198
# PESQ Score for real_19616.wav and fake_19616.wav: 1.084611177444458
# PESQ Score for real_19642.wav and fake_19642.wav: 1.1332756280899048
# PESQ Score for real_19722.wav and fake_19722.wav: 1.0887223482131958
# PESQ Score for real_19848.wav and fake_19848.wav: 1.4998397827148438
# PESQ Score for real_19966.wav and fake_19966.wav: 1.5139187574386597
# PESQ Score for real_20084.wav and fake_20084.wav: 1.1866803169250488
# PESQ Score for real_20299.wav and fake_20299.wav: 1.1113580465316772
# PESQ Score for real_20330.wav and fake_20330.wav: 1.1499305963516235
# PESQ Score for real_20870.wav and fake_20870.wav: 1.0373777151107788
# PESQ Score for real_21042.wav and fake_21042.wav: 1.1002308130264282
# PESQ Score for real_21140.wav and fake_21140.wav: 1.0603224039077759
# PESQ Score for real_21568.wav and fake_21568.wav: 1.0481570959091187
# PESQ Score for real_21766.wav and fake_21766.wav: 1.088217854499817
# PESQ Score for real_22349.wav and fake_22349.wav: 1.3180155754089355
# Average PESQ Score for the batch: 1.3927264404296875

# %% [markdown]
# ## BEST PESQ:
#
# Audio size: 15
#
# ckpt = checkpoint of our trained model
#
# Sampling Rate: **8K**
# - 1.06 [70K ckpt]
# - 1.07 [130K ckpt] **
# - 1.05 [140K ckpt]
#
# ---
#
# Sampling Rate: **16K**
# - 1.09 [70K ckpt]
# - 1.13 [130K ckpt] **
# - 1.10 [140K ckpy]
#
# ---
#
# Sampling Rate: **22.5K**
# - 1.24 [70K ckpt] **
# - 1.16 [130K ckpt]
# - 1.12 [140K ckpt]
#
# ---
# ---
#
# Audio size: 100
#
# Sampling Rate: **22K**
# - 1.17 [140K ckpt]
# - **1.39 [130 ckpt]**
# - 1.23 [70 ckpt] **

# %% [markdown]
# ## STOI
# The STOI (Short-Time Objective Intelligibility) metric is designed to assess the intelligibility of speech signals, and it is particularly useful when **evaluating how much speech has been degraded or distorted**.
#
# The score reflects the **quality of speech perception by humans**, even when the speech is corrupted by noise, distortion, or other impairments.
#
# The scores can be interpreted as follows:
#
# - 0.9 to 1.0: Very high intelligibility. The generated speech is almost indistinguishable from the original.
# - 0.7 to 0.9: Good intelligibility, but there may be slight distortions or noise present that affect understanding.
# - 0.5 to 0.7: Moderate intelligibility. The speech is somewhat degraded, and parts of it might be difficult to understand, especially under noisy conditions.
# - Below 0.5: Poor intelligibility. The speech is heavily degraded or distorted, and it may be difficult or impossible to understand most or all of the content.

# %%
# !pip install pystoi
# Out:
# Collecting pystoi
#   Downloading pystoi-0.4.1-py2.py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pystoi) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pystoi) (1.13.1)
# Downloading pystoi-0.4.1-py2.py3-none-any.whl (8.2 kB)
# Installing collected packages: pystoi
# Successfully installed pystoi-0.4.1

# %%
from pystoi import stoi
import scipy.io.wavfile as wav
import numpy as np

# Load the real and fake audio files
fs_real, real_audio = wav.read(real)
fs_fake, fake_audio = wav.read(fake)

# Ensure both signals have the same sample rate
assert fs_real == fs_fake, "Sample rates must be the same."

# Get the minimum length of the two signals
min_length = min(len(real_audio), len(fake_audio))

# Trim both signals to the minimum length
real_audio = real_audio[:min_length]
fake_audio = fake_audio[:min_length]

# Calculate STOI score
stoi_score = stoi(real_audio, fake_audio, fs_real)
print("STOI Score:", stoi_score)
# Out:
# STOI Score: 0.18200571635120377

# %% [markdown]
# ## **EER** is used for mainly **speaker verificaion** when we have multiple speakers. So its of **NO USE in our case** as ours is a single speaker system.

# %% [markdown]
# Recommended Approach:
# For generating fake audio (e.g., synthetic speech or manipulated audio), the following metrics are typically more useful:
#
# PESQ: For speech or general audio quality.
# MOS: For a comprehensive, human-perception-based quality assessment.
# SNR: To detect distortions and measure how much noise is introduced in the fake audio.
# STOI: If intelligibility is crucial (e.g., for speech applications).
# These metrics provide different perspectives on audio quality:
#
# PESQ and MOS measure the overall quality from a perceptual standpoint.
# SNR quantifies the signal distortion.
# STOI evaluates intelligibility, especially in speech.
# You can use a combination of these metrics depending on the characteristics you're most concerned with (e.g., intelligibility, perceptual quality, noise levels).

# %% [markdown]
# To assess **Overall Quality**, **Naturalness**, and **Content Clarity** of audio, the following metrics are best suited:
#
# ### 1. **Overall Quality**:
#    - **Metric**: **PESQ (Perceptual Evaluation of Speech Quality)**
#      - **Reason**: PESQ is widely used for evaluating overall speech quality. It accounts for various distortions, including compression artifacts, noise, and other impairments, giving a comprehensive measure of the perceived quality of speech.
#      - **Reference**: The PESQ algorithm has been standardized by ITU-T (P.862), and is commonly used in telecommunications and audio quality research.
#
# ### 2. **Naturalness**:
#    - **Metric**: **MOS (Mean Opinion Score) or Subjective Rating** (specifically focused on naturalness)
#      - **Reason**: MOS is an established subjective method to assess how "natural" the audio sounds to human listeners. It directly reflects the perceived naturalness based on human judgment, which is critical when assessing whether synthetic speech or audio sounds natural.
#      - **Reference**: MOS has been a standard for subjective assessment of speech and audio quality, particularly in speech synthesis and voice applications (e.g., ITU-T P.800).
#
# ### 3. **Content Clarity**:
#    - **Metric**: **STOI (Short-Time Objective Intelligibility)**
#      - **Reason**: STOI measures how intelligible speech is under varying conditions. It quantifies the preservation of content clarity by comparing the reference and degraded speech. Higher STOI values indicate better content clarity, especially in noisy or degraded environments.
#      - **Reference**: STOI has been widely used in speech enhancement research (e.g., ITU-T P.862.2 for speech intelligibility).
#
# ### **Conclusion**:
# - **PESQ** for **Overall Quality** provides a comprehensive measure of how good the audio sounds.
# - **MOS** for **Naturalness** captures how human listeners perceive the naturalness of the audio.
# - **STOI** for **Content Clarity** focuses on intelligibility, which directly relates to the clarity of the audio's content.
